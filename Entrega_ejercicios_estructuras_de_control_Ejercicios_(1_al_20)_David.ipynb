# %% [markdown]
# <a href="https://colab.research.google.com/github/dvdch1258/phyton/blob/main/Entrega_ejercicios_estructuras_de_control_Ejercicios_(1_al_20)_David.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Ejercicio 1
Algoritmo que pida dos números e indique si el primero es mayor que el segundo o no.

"""

num1 = int(input("Dame un número: "))
num2 = int(input("Dame otro número: "))
if num1 > num2:
    print("El primer número es mayor que el segundo")
else:
    print("El primer número no es mayor que el segundo")
# Out:
# Dame un número: 4
# Dame otro número: 6
# El primer número no es mayor que el segundo

# %%
"""
Ejercicio 2
Algoritmo que pida un número y diga si es positivo, negativo o 0.

"""

num = int(input("Dame un número: "))
if num > 0:
    print("El número es positivo")
elif num < 0:
    print("El número es negativo")
else:
    print("El número es 0")
# Out:
# Dame un número: 4
# El número es positivo

# %%
"""
Ejercicio 3
Escribe un programa que lea un número e indique si es par o impar.

"""

num = int(input("Dame un número: "))
if num % 2 == 0:
    print("El número es par")
else:
    print("El número es impar")
# Out:
# Dame un número: 2
# El número es par

# %%
"""
Ejercicio 4
Crea un programa que pida al usuario dos números y muestre su división si el segundo no es cero, o un mensaje de aviso en caso contrario.

"""

num1 = int(input("Dame el primer número: "))
num2 = int(input("Dame el segundo número: "))
if num2 > 0:
        print(num1 / num2)
else:
        print("No se puede dividir por cero")
# Out:
# Dame el primer número: 8
# Dame el segundo número: 4
# 2.0

# %%
"""
Ejercicio 5
Escribe un programa que pida un nombre de usuario y una contraseña y si se ha introducido “pepe” y “asdasd” se indica “Has entrado al sistema”, sino se da un error.

"""

usaurio = input("Dame un nombre de usuario: ")
contraseña = input("Dame una contraseña: ")
if usaurio == "pepe" and contraseña == "asdasd":
    print("Has entrado al sistema")
else:
    print("Error")
# Out:
# Dame un nombre de usuario: pepe
# Dame una contraseña: asdasd
# Has entrado al sistema

# %%
"""
Ejercicio 6
Programa que lea una cadena por teclado y compruebe si es una letra mayúscula.

"""
cadena = input("Dame una cadena: ")
if cadena.isupper():
    print("La cadena es una letra mayúscula")
else:
    print("La cadena no es una letra mayúscula")
# Out:
# Dame una cadena: LARA
# La cadena es una letra mayúscula

# %%
"""
Ejercicio 7
Realiza un algoritmo que calcule la potencia, para ello pide por teclado la base y el exponente. Pueden ocurrir tres cosas:

"""
base = int(input("Dame la base: "))
exponente = int(input("Dame el exponente: "))
if exponente > 0:
    print(base ** exponente)
elif exponente == 0:
    print(1)
else:
    print("El exponente debe ser mayor a cero")
# Out:
# Dame la base: 6
# Dame el exponente: 4
# 1296

# %%
"""
Ejercicio 8
Algoritmo que pida dos números ‘nota’ y ‘edad’ y un carácter ‘sexo’ y muestre el
mensaje ‘ACEPTADA’ si la nota es mayor o igual a cinco, la edad es mayor o igual a
dieciocho y el sexo es ‘F’. En caso de que se cumpla lo mismo, pero el sexo sea ‘M’, debe
imprimir ‘POSIBLE’. Si no se cumplen dichas condiciones se debe mostrar ‘NO ACEPTADA’.

"""

nota = int(input("Dame la nota:"))
edad = int(input("Dame la edad: "))
sexo = input("Dame el sexo: ")
if nota >= 5 and edad >= 18 and sexo == "F":
    print("ACEPTADA")
elif nota >= 5 and edad >= 18 and sexo == "M":
    print("POSIBLE")
else:
    print("NO ACEPTADA")
# Out:
# Dame la nota:6
# Dame la edad: 20
# Dame el sexo: F
# ACEPTADA

# %%
"""
Ejercicio 9
Algoritmo que pida tres números y los muestre ordenados (de mayor a menor);

"""

num1 = int(input("Dame el primer número: "))
num2 = int(input("Dame el segundo número: "))
num3 = int(input("Dame el tercer número: "))
if num1 > num2 and num1 > num3:
    if num2 > num3:
        print(num1, num2, num3)
    else:
        print(num1, num3, num2)
if num2 > num1 and num2 > num3:
    if num1 > num3:
        print(num2, num1, num3)
    else:
        print(num2, num3, num1)
if num3 > num1 and num3 > num2:
    if num1 > num2:
        print(num3, num1, num2)
    else:
        print(num3, num2, num1)
# Out:
# Dame el primer número: 7
# Dame el segundo número: 8
# Dame el tercer número: 9
# 9 8 7

# %%
"""

Ejercicio 10
Algoritmo que pida los puntos centrales x1,y1,x2,y2 y los radios r1,r2 de dos
circunferencias y las clasifique en uno de estos estados:

exteriores
tangentes exteriores
secantes
tangentes interiores
interiores
concéntricas

"""

x1 = int(input("Dame el punto central x1: "))
x2 = int(input("Dame el punto central x2:"))
y1 = int(input("Dame el punto central y1:"))
y2 = int(input("Dame el punto central y2: "))
r1 = int(input("Dame el radio r1: "))
r2 = int(input("Dame el radio r2: "))
d = ((x2 - x1)**2 + (y2 - y1)**2)**0.5
if d > r1 + r2:
    print("Las circunferencias están exteriores")
if d == r1 + r2:
        print("Las circunferencias son tangentes exteriores")
elif d < r1 + r2:
    print("Las circunferencias están interiores")
if d == abs(r1 - r2):
        print("Las circunferencias son concéntricas")
elif d < abs(r1 - r2):
        print("Las circunferencias están secantes")
if d > abs(r1 - r2) and d < r1 + r2:
        print("Las circunferencias son tangentes interiores")
# Out:
# Dame el punto central x1: 5
# Dame el punto central x2:5
# Dame el punto central y1:4
# Dame el punto central y2: 9
# Dame el radio r1: 5
# Dame el radio r2: 6
# Las circunferencias están interiores
# Las circunferencias son tangentes interiores

# %%
"""
Ejercicio 11
Programa que lea 3 datos de entrada A, B y C. Estos corresponden a las dimensiones de los lados de un triángulo. El programa debe determinar que tipo de triangulo es, teniendo en cuenta los siguiente:

Si se cumple Pitágoras entonces es triángulo rectángulo
Si sólo dos lados del triángulo son iguales entonces es isósceles.
Si los 3 lados son iguales entonces es equilátero.
Si no se cumple ninguna de las condiciones anteriores, es escaleno.

"""

A = int(input("Dame el primer lado: "))
B = int(input("Dame el segundo lado: "))
C = int(input("Dame el tercer lado: "))
if A**2 == B**2 + C**2:
    print("El triángulo es rectángulo")
if A == B and B == C:
    print("El triángulo es equilátero")
elif A == B or B == C or A == C:
    print("El triángulo es isósceles")
else:
    print("El triángulo es escaleno")
# Out:
# Dame el primer lado: 4
# Dame el segundo lado: 4
# Dame el tercer lado: 4
# El triángulo es equilátero

# %%
"""
Ejercicio 12
Escribir un programa que lea un año indicar si es bisiesto. Nota: un año es bisiesto si es un número divisible por 4, pero no si es divisible por 100, excepto que también sea divisible por 400.

"""

año = int(input("Dame un año: "))
if año % 4 == 0 and año % 100 != 0 or año % 400 == 0:
    print("El año es bisiesto")
else:
    print("El año no es bisiesto")
# Out:
# Dame un año: 2024
# El año es bisiesto

# %%
"""
Ejercicio 13
Escribe un programa que pida una fecha (día, mes y año) y diga si es correcta.

"""

día = int(input("Dame el día: "))
mes = int(input("Dame el mes: "))
año = int(input("Dame el año: "))
if mes == 1 or mes == 3 or mes == 5 or mes == 7 or mes == 8 or mes == 10 or mes == 12:
    if día <= 31:
        print("La fecha es correcta")
    else:
        print("La fecha no es correcta")
# Out:
# Dame el día: 5
# Dame el mes: 3
# Dame el año: 2025
# La fecha es correcta

# %%
"""
Ejercicio 14
La asociación de vinicultores tiene como política fijar un precio inicial al kilo de uva, la cual se clasifica en tipos A y B, y además en tamaños 1 y 2. Cuando se realiza la venta del producto, ésta es de un solo tipo y tamaño, se requiere determinar cuánto recibirá un productor por la uva que entrega en un embarque, considerando lo siguiente: si es de tipo A,
se le cargan 20 céntimos al precio inicial cuando es de tamaño 1; y 30 céntimos si es de tamaño 2. Si es de tipo B, se rebajan 30 céntimos cuando es de tamaño 1, y 50 céntimos cuando es de tamaño 2. Realice un algoritmo para determinar la ganancia obtenida.

"""


precio_inicial = float(input("Precio inicial por kilo de uva: "))
tipo = input("Tipo de uva (A/B): ").upper()
tamaño = int(input("Tamaño de la uva (1/2): "))
kilos = float(input("Cantidad de kilos entregados: "))


if tipo == "A":
    if tamaño == 1:
        precio_final = precio_inicial + 0.20
    elif tamaño == 2:
        precio_final = precio_inicial + 0.30
    else:
        print("Tamaño inválido")
        precio_final = 0
elif tipo == "B":
    if tamaño == 1:
        precio_final = precio_inicial - 0.30
    elif tamaño == 2:
        precio_final = precio_inicial - 0.50
    else:
        print("Tamaño inválido")
        precio_final = 0
else:
    print("Tipo inválido")
    precio_final = 0

ganancia = precio_final * kilos

if precio_final != 0:
    print(f"La ganancia obtenida es: {ganancia:.2f} euros")
# Out:
# Precio inicial por kilo de uva: 20
# Tipo de uva (A/B): A
# Tamaño de la uva (1/2): 1
# Cantidad de kilos entregados: 560
# La ganancia obtenida es: 11312.00 euros

# %%
"""
Ejercicio 15
El director de una escuela está organizando un viaje de estudios, y requiere determinar cuánto debe cobrar a cada alumno y cuánto debe pagar a la compañía de viajes por el servicio. La forma de cobrar es la siguiente: si son 100 alumnos o más, el costo por cada alumno es de 65 euros; de 50 a 99 alumnos, el costo es de 70 euros, de 30 a 49, de 95 euros, y si son menos de 30, el costo de la renta del autobús es de 4000 euros, sin importar el número de alumnos.
Realice un algoritmo que permita determinar el pago a la compañía de autobuses y lo que debe pagar cada alumno por el viaje.

"""


num_alumnos = int(input("Número de alumnos: "))


if num_alumnos >= 100:
    costo_por_alumno = 65
    pago_total = num_alumnos * costo_por_alumno
    pago_por_alumno = costo_por_alumno
elif num_alumnos >= 50:
    costo_por_alumno = 70
    pago_total = num_alumnos * costo_por_alumno
    pago_por_alumno = costo_por_alumno
elif num_alumnos >= 30:
    costo_por_alumno = 95
    pago_total = num_alumnos * costo_por_alumno
    pago_por_alumno = costo_por_alumno
else:
    pago_total = 4000
    pago_por_alumno = pago_total / num_alumnos


print(f"Pago total a la compañía: {pago_total:.2f} euros")
print(f"Pago por alumno: {pago_por_alumno:.2f} euros")
# Out:
# Número de alumnos: 50
# Pago total a la compañía: 3500.00 euros
# Pago por alumno: 70.00 euros

# %%
"""
Ejercicio 16
La política de cobro de una compañía telefónica es: cuando se realiza una llamada, el cobro es por el tiempo que ésta dura, de tal forma que los primeros cinco minutos cuestan 1 euro, los siguientes tres, 80 céntimos, los siguientes dos minutos, 70 céntimos, y a partir del décimo minuto, 50 céntimos.
Además, se carga un impuesto de 3 % cuando es domingo, y si es otro día, en turno de mañana, 15 %, y en turno de tarde, 10 %. Realice un algoritmo para determinar cuánto debe pagar por cada concepto una persona que realiza una llamada.

"""




duracion = float(input("Duración de la llamada en minutos: "))
dia = input("Día de la semana: ").lower()
if dia == "domingo":
    impuesto = 3
else:
    turno = input("Turno (mañana/tarde): ").lower()
    if turno == "mañana":
        impuesto = 15
    else:
        impuesto = 10
if duracion <= 5:
    costo_base = 1
elif duracion <= 8:
    costo_base = 1 + (duracion - 5) * 0.80
elif duracion <= 10:
    costo_base = 1 + 3 * 0.80 + (duracion - 8) * 0.70
else:
    costo_base = 1 + 3 * 0.80 + 2 * 0.70 + (duracion - 10) * 0.50


costo_impuesto = costo_base * impuesto / 100
costo_total = costo_base + costo_impuesto

print(f"Costo base: {costo_base:.2f} euros")
print(f"Impuesto ({impuesto}%): {costo_impuesto:.2f} euros")
print(f"Costo total: {costo_total:.2f} euros")
# Out:
# Duración de la llamada en minutos: 72
# Día de la semana: 5
# Turno (mañana/tarde): mañana
# Costo base: 35.80 euros
# Impuesto (15%): 5.37 euros
# Costo total: 41.17 euros

# %%
"""
Ejercicio 17
Realiza un programa que pida por teclado el resultado (dato entero) obtenido al lanzar un dado de seis caras y muestre por pantalla el número en letras (dato cadena) de la cara opuesta al resultado obtenido.

Nota 1: En las caras opuestas de un dado de seis caras están los números: 1-6, 2-5 y 3-4.
Nota 2: Si el número del dado introducido es menor que 1 o mayor que 6, se mostrará el mensaje: “ERROR: número incorrecto.”.

"""
numeros_letras = {
    1: "uno",
    2: "dos",
    3: "tres",
    4: "cuatro",
    5: "cinco",
    6: "seis"
}

resultado = int(input("Introduce el resultado del dado (1-6): "))
if resultado < 1 or resultado > 6:
    print("[translate:ERROR: número incorrecto.]")
else:
    opuesto = 7 - resultado
    print(f"La cara opuesta es: {numeros_letras[opuesto]}")
# Out:
# Introduce el resultado del dado (1-6): 2
# La cara opuesta es: cinco

# %%
"""
Ejercicio 18
Realiza un programa que pida el día de la semana (del 1 al 7) y escriba el día correspondiente. Si introducimos otro número nos da un error.

"""

dias_semana = {
    1: "lunes",
    2: "martes",
    3: "miércoles",
    4: "jueves",
    5: "viernes",
    6: "sábado",
    7: "domingo"
}

numero = int(input("Introduce un número del 1 al 7: "))
if 1 <= numero <= 7:
    print(f"El día correspondiente es: {dias_semana[numero]}")
else:
    print("[translate:ERROR: número incorrecto.]")
# Out:
# Introduce un número del 1 al 7: 3
# El día correspondiente es: miércoles

# %%
"""
Ejercicio 19
Escribe un programa que pida un número entero entre uno y doce e imprima el número de días que tiene el mes correspondiente.

"""
dias_por_mes = {
    1: 31,  # enero
    2: 28,  # febrero
    3: 31,  # marzo
    4: 30,  # abril
    5: 31,  # mayo
    6: 30,  # junio
    7: 31,  # julio
    8: 31,  # agosto
    9: 30,  # septiembre
    10: 31, # octubre
    11: 30, # noviembre
    12: 31  # diciembre
}

# Pedir número de mes
mes = int(input("Introduce un número de mes entre 1 y 12: "))

# Validar y mostrar resultados
if 1 <= mes <= 12:
    print(f"El mes {mes} tiene {dias_por_mes[mes]} días")
else:
    print("[translate:ERROR: número incorrecto.]")
# Out:
# Introduce un número de mes entre 1 y 12: 4
# El mes 4 tiene 30 días

# %%
"""
Ejercicio 20
Una compañía de transporte internacional tiene servicio en algunos países de América del Norte, América Central, América del Sur, Europa y Asia. El costo por el servicio de transporte se basa en el peso del paquete y la zona a la que va dirigido. Lo anterior se muestra en la tabla:

"""

coste_gramo = {
    1: 24.00,  # América del Norte
    2: 20.00,  # América Central
    3: 21.00,  # América del Sur
    4: 10.00,  # Europa
    5: 18.00   # Asia
}

zona = int(input("Introduce la zona (1-América del Norte, 2-América Central, 3-América del Sur, 4-Europa, 5-Asia): "))
peso_kg = float(input("Introduce el peso del paquete en kg: "))

if peso_kg > 5:
    print("[translate:El paquete no puede ser transportado por superar los 5 kg.]")
elif zona not in coste_gramo:
    print("[translate:Zona inválida.]")
else:
    # Calcular costo: convertir kg a gramos multiplicando por 1000
    peso_gramos = peso_kg * 1000
    costo = peso_gramos * coste_gramo[zona]
    print(f"El costo por la entrega es: {costo:.2f} euros")
# Out:
# Introduce la zona (1-América del Norte, 2-América Central, 3-América del Sur, 4-Europa, 5-Asia): 2
# Introduce el peso del paquete en kg: 25
# [translate:El paquete no puede ser transportado por superar los 5 kg.]
